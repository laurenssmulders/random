# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def calculate_energy(k_x, k_y, t_1=-2, t_2=-1, a=1, b=2):
    E = 2 * t_1 * np.cos(a*k_x) + 2 * t_2 * np.cos(b*k_y)
    return E

# %%
# Looking at the first Brillouin zone
a = 1
b = 2
k_x = np.linspace(-np.pi/a, np.pi/a, 1000)
k_y = np.linspace(-np.pi/b, np.pi/b, 1000)

K_X, K_Y = np.meshgrid(x,y)
E = calculate_energy(K_X, K_Y, a=a, b=b)

# %%
plt.contour(K_X, K_Y, E)

# %%
# Looking at density of states, using a uniform density of k_states
k_density = 1 / (2 * np.pi**2)
E_hist = np.reshape(E, 1000000)
plt.hist(E_hist, bins=500, density=True)
plt.show()
